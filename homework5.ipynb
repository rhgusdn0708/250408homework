# %%
# %pip show requests
# Out:
# Name: requests
# Version: 2.32.3
# Summary: Python HTTP for Humans.
# Home-page: https://requests.readthedocs.io
# Author: Kenneth Reitz
# Author-email: me@kennethreitz.org
# License: Apache-2.0
# Location: c:\Users\qwer\anaconda3\Lib\site-packages
# Requires: certifi, charset-normalizer, idna, urllib3
# Required-by: aext-assistant-server, anaconda-catalogs, anaconda-client, anaconda-cloud-auth, anaconda-project, conda, conda-build, conda-repo-cli, conda_package_streaming, cookiecutter, datashader, jupyterlab_server, panel, requests-file, requests-toolbelt, Sphinx, streamlit, tldextract
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip show beautifulsoup4
# Out:
# Name: beautifulsoup4
# Version: 4.12.3
# Summary: Screen-scraping library
# Home-page: https://www.crummy.com/software/BeautifulSoup/bs4/
# Author:
# Author-email: Leonard Richardson <leonardr@segfault.org>
# License: MIT License
# Location: c:\Users\qwer\anaconda3\Lib\site-packages
# Requires: soupsieve
# Required-by: conda-build, nbconvert
# Note: you may need to restart the kernel to use updated packages.

# %%
#질문 :  검색어로  찾은  책 목록 출력하기

import requests
import json
import pandas as pd
from datetime import datetime


CLIENT_ID = 'k0utHowdu79ZStSxeLO8'
CLIENT_SECRET = 'x9j6cIZotu'

headers = {
    'X-Naver-Client-Id': CLIENT_ID,
    'X-Naver-Client-Secret': CLIENT_SECRET
}

def search_books(query):
    """네이버 책 검색 API를 호출하여 결과를 반환"""
    payload = {
        'query': query,
        'display': 30,
        'sort': 'sim'
    }
    
    url = 'https://openapi.naver.com/v1/search/book.json'
    res = requests.get(url, params=payload, headers=headers)
    res.raise_for_status() 
    
    return res.json()['items']

def save_to_json(data, filename):
    """데이터를 JSON 파일로 저장"""
    with open(filename, 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=2)

def format_book_data(books):
    """책 데이터를 출력 형식에 맞게 포매팅"""
    formatted_books = []
    for book in books:
       
        pubdate = book.get('pubdate', '')
        if pubdate and len(pubdate) == 8:
            try:
                pubdate = f"{pubdate[:4]}-{pubdate[4:6]}-{pubdate[6:8]}"
            except:
                pass
 
        price = book.get('price', '0')
        try:
            price = f"{int(price):,}"
        except:
            price = '0'
        
    
        description = book.get('description', '')
        if len(description) > 100:
            description = description[:100] + '...'
        
        formatted_book = {
            '제목': book.get('title', '').replace('<b>', '').replace('</b>', ''),
            '저자': book.get('author', ''),
            '출판사': book.get('publisher', ''),
            '출판일': pubdate,
            '가격': price,
            '설명': description,
            '링크': book.get('link', '')
        }
        formatted_books.append(formatted_book)
    
    return formatted_books

def print_books(books):
    """포매팅된 책 목록 출력"""
    for i, book in enumerate(books, 1):
        print(f"\n[{i}] {book['제목']}")
        print(f"저자: {book['저자']}")
        print(f"출판사: {book['출판사']}")
        print(f"출판일: {book['출판일']}")
        print(f"가격: {book['가격']}원")
        print(f"설명: {book['설명']}")
        print(f"링크: {book['링크']}")

def main():
   
    query = input("검색할 책 제목 또는 키워드를 입력하세요: ")
    
    try:
       
        books = search_books(query)
        save_to_json(books, 'data/books.json')
        print("책 검색 결과가 data/books.json 파일에 저장되었습니다.")
        
     
        df = pd.DataFrame(books)
        print("\nDataFrame 정보:")
        print(df.info())
        
       
        formatted_books = format_book_data(books)
        print("\n검색 결과:")
        print_books(formatted_books)
        
    except Exception as e:
        print(f"오류 발생: {e}")

if __name__ == "__main__":
    main()

# %%
# 질문 :  검색어로  찾은  책 목록 중에서 가격이 2만원 이상인 책만 출력하기

import requests
import json
import pandas as pd
from datetime import datetime

CLIENT_ID = 'k0utHowdu79ZStSxeLO8'
CLIENT_SECRET = 'x9j6cIZotu'

headers = {
    'X-Naver-Client-Id': CLIENT_ID,
    'X-Naver-Client-Secret': CLIENT_SECRET
}

def search_books(query):
    """네이버 책 검색 API를 호출하여 결과를 반환"""
    payload = {
        'query': query,
        'display': 30,
        'sort': 'sim'
    }
    
    url = 'https://openapi.naver.com/v1/search/book.json'
    res = requests.get(url, params=payload, headers=headers)
    res.raise_for_status() 
    
    return res.json()['items']

def save_to_json(data, filename):
    """데이터를 JSON 파일로 저장"""
    with open(filename, 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=2)

def format_book_data(books):
    """책 데이터를 출력 형식에 맞게 포매팅"""
    formatted_books = []
    for book in books:
     
        pubdate = book.get('pubdate', '')
        if pubdate and len(pubdate) == 8:
            try:
                pubdate = f"{pubdate[:4]}-{pubdate[4:6]}-{pubdate[6:8]}"
            except:
                pass
        
   
        price = book.get('price', '0')
        try:
            price = f"{int(price):,}"
        except:
            price = '0'
        
  
        description = book.get('description', '')
        if len(description) > 100:
            description = description[:100] + '...'
        
        formatted_book = {
            '제목': book.get('title', '').replace('<b>', '').replace('</b>', ''),
            '저자': book.get('author', ''),
            '출판사': book.get('publisher', ''),
            '출판일': pubdate,
            '가격': price,
            '설명': description,
            '링크': book.get('link', '')
        }
        formatted_books.append(formatted_book)
    
    return formatted_books

def print_books(books):
    """포매팅된 책 목록 출력"""
    for i, book in enumerate(books, 1):
        print(f"\n[{i}] {book['제목']}")
        print(f"저자: {book['저자']}")
        print(f"출판사: {book['출판사']}")
        print(f"출판일: {book['출판일']}")
        print(f"가격: {book['가격']}원")
        print(f"설명: {book['설명']}")
        print(f"링크: {book['링크']}")

def main():
  
    query = input("검색할 책 제목 또는 키워드를 입력하세요: ")
    
    try:
       
        books = search_books(query)
        save_to_json(books, 'data/books.json')
        print("책 검색 결과가 data/books.json 파일에 저장되었습니다.")
        
    
        df = pd.DataFrame(books)
        
        
        df['discount'] = pd.to_numeric(df['discount'], errors='coerce')
        
    
        expensive_books = df[df['discount'] >= 20000]
        
        if not expensive_books.empty:
            print("\n[가격이 2만원 이상인 책 목록]")
           
            result = expensive_books[['title', 'author', 'discount', 'publisher', 'pubdate']]
            result = result.sort_values('discount', ascending=False).reset_index(drop=True)
            
          
            result.columns = ['제목', '저자', '가격', '출판사', '출판일']
            
          
            result['가격'] = result['가격'].apply(lambda x: f"{int(x):,}원")
            
            print(result)
        else:
            print("\n2만원 이상인 책이 없습니다.")
        
       
        formatted_books = format_book_data(books)
        print("\n[전체 검색 결과]")
        print_books(formatted_books)
        
    except Exception as e:
        print(f"오류 발생: {e}")
        
        

if __name__ == "__main__":
    main()

# %%
#질문 : 검색어로  찾은  책 목록 중에서 출판사가 인피니티북스인 책만 출력하기


import requests
import json
import pandas as pd
from datetime import datetime

CLIENT_ID = 'k0utHowdu79ZStSxeLO8'
CLIENT_SECRET = 'x9j6cIZotu'

headers = {
    'X-Naver-Client-Id': CLIENT_ID,
    'X-Naver-Client-Secret': CLIENT_SECRET
}

def search_books(query):
    """네이버 책 검색 API를 호출하여 결과를 반환"""
    payload = {
        'query': query,
        'display': 30,
        'sort': 'sim'
    }
    
    url = 'https://openapi.naver.com/v1/search/book.json'
    res = requests.get(url, params=payload, headers=headers)
    res.raise_for_status() 
    
    return res.json()['items']

def save_to_json(data, filename):
    """데이터를 JSON 파일로 저장"""
    with open(filename, 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=2)

def format_book_data(books):
    """책 데이터를 출력 형식에 맞게 포매팅"""
    formatted_books = []
    for book in books:
     
        pubdate = book.get('pubdate', '')
        if pubdate and len(pubdate) == 8:
            try:
                pubdate = f"{pubdate[:4]}-{pubdate[4:6]}-{pubdate[6:8]}"
            except:
                pass
        
   
        price = book.get('price', '0')
        try:
            price = f"{int(price):,}"
        except:
            price = '0'
        
  
        description = book.get('description', '')
        if len(description) > 100:
            description = description[:100] + '...'
        
        formatted_book = {
            '제목': book.get('title', '').replace('<b>', '').replace('</b>', ''),
            '저자': book.get('author', ''),
            '출판사': book.get('publisher', ''),
            '출판일': pubdate,
            '가격': price,
            '설명': description,
            '링크': book.get('link', '')
        }
        formatted_books.append(formatted_book)
    
    return formatted_books

def print_books(books):
    """포매팅된 책 목록 출력"""
    for i, book in enumerate(books, 1):
        print(f"\n[{i}] {book['제목']}")
        print(f"저자: {book['저자']}")
        print(f"출판사: {book['출판사']}")
        print(f"출판일: {book['출판일']}")
        print(f"가격: {book['가격']}원")
        print(f"설명: {book['설명']}")
        print(f"링크: {book['링크']}")

def main():
   
    query = input("검색할 책 제목 또는 키워드를 입력하세요: ")
    
    try:
     
        books = search_books(query)
        save_to_json(books, 'data/books.json')
        print("책 검색 결과가 data/books.json 파일에 저장되었습니다.")
        
   
        df = pd.DataFrame(books)
        
       
        infinity_books = df[df['publisher'].str.contains('인피니티북스', na=False)]
        
        if not infinity_books.empty:
            print("\n[출판사: 인피니티북스 책 목록]")
           
            result = infinity_books.drop(columns=['image', 'description'], errors='ignore')
            
        
            existing_columns = result.columns.tolist()
            column_mapping = {
                'title': '제목',
                'author': '저자',
                'price': '가격',
                'publisher': '출판사',
                'pubdate': '출판일',
                'isbn': 'ISBN',
                'link': '링크',
                'discount': '할인가'
            }
            
           
            new_columns = [column_mapping.get(col, col) for col in existing_columns]
            result.columns = new_columns
            
           
            result = result.reset_index(drop=True)
            
            print(result)
        else:
            print("\n인피니티북스 출판사의 책이 없습니다.")
        
      
        formatted_books = format_book_data(books)
        print("\n[전체 검색 결과]")
        print_books(formatted_books)
        
    except Exception as e:
        print(f"오류 발생: {e}")
        
    
if __name__ == "__main__":
    main()
